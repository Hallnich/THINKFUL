# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy 
import sklearn
from sklearn import linear_model
# %matplotlib inline

# %%
# Read in data
df = pd.read_csv('C:\\Users\halln\Desktop\THINKFUL\Datasets\FBI_Table_Drill\data.csv',skiprows=4)

# %%
df.columns
# Out:
# Index(['City', 'Population', 'Violent\ncrime',
#        'Murder and\nnonnegligent\nmanslaughter',
#        'Rape\n(revised\ndefinition)1', 'Rape\n(legacy\ndefinition)2',
#        'Robbery', 'Aggravated\nassault', 'Property\ncrime', 'Burglary',
#        'Larceny-\ntheft', 'Motor\nvehicle\ntheft', 'Arson3'],
#       dtype='object')

# %%
# Check types of data contained in dataframe
df.dtypes
# Out:
# City                                       object
# Population                                float64
# Violent\ncrime                            float64
# Murder and\nnonnegligent\nmanslaughter    float64
# Rape\n(revised\ndefinition)1              float64
# Rape\n(legacy\ndefinition)2               float64
# Robbery                                   float64
# Aggravated\nassault                       float64
# Property\ncrime                           float64
# Burglary                                  float64
# Larceny-\ntheft                           float64
# Motor\nvehicle\ntheft                     float64
# Arson3                                    float64
# dtype: object

# %%
# Collect only columns of interest into new dataframe
data= pd.DataFrame(df['Population'])
data['Population_Squared'] = df.loc[:,'Population']**2
data[['Murder','Robbery','Property_Crime']] = df[['Murder and\nnonnegligent\nmanslaughter','Robbery','Property\ncrime']]

# Check to see which columns contain NA values
data.isna().sum()
# Out:
# Population            3
# Population_Squared    3
# Murder                3
# Robbery               3
# Property_Crime        3
# dtype: int64

# %%
# Drop rows containing NA values
data = data.dropna()

# %%
# Add binary indicators for murders and robberies
data['Murders_Occurring?'] = data.loc[:,'Murder'].apply(lambda x: x>=1)
data['Robberies_Occurring?'] = data.loc[:,'Robbery'].apply(lambda x: x>=1)

# %%
# Collect only variables needed for model
df = data[['Population','Population_Squared','Murders_Occurring?','Robberies_Occurring?','Property_Crime']]
df
# Out:
#      Population  Population_Squared  Murders_Occurring?  Robberies_Occurring?  \
# 0        1861.0        3.463321e+06               False                 False
# 1        2577.0        6.640929e+06               False                 False
# 2        2846.0        8.099716e+06               False                 False
# 3       97956.0        9.595378e+09                True                  True
# 4        6388.0        4.080654e+07               False                  True
# 5        4089.0        1.671992e+07               False                  True
# 6        1781.0        3.171961e+06               False                 False
# 7      118296.0        1.399394e+10                True                  True
# 8        9519.0        9.061136e+07               False                  True
# 9       18182.0        3.305851e+08               False                  True
# 10       2053.0        4.214809e+06               False                 False
# 11       4523.0        2.045753e+07               False                  True
# 12        658.0        4.329640e+05               False                 False
# 13       2522.0        6.360484e+06               False                 False
# 14      27270.0        7.436529e+08                True                  True
# 15       3333.0        1.110889e+07               False                  True
# 16       7473.0        5.584573e+07               False                  True
# 17       5418.0        2.935472e+07               False                  True
# 18      15374.0        2.363599e+08               False                  True
# 19       5733.0        3.286729e+07               False                  True
# 20      17627.0        3.107111e+08               False                  True
# 21      34243.0        1.172583e+09               False                  True
# 22      46304.0        2.144060e+09                True                  True
# 23       1410.0        1.988100e+06               False                 False
# 24      12001.0        1.440240e+08               False                 False
# 25       1022.0        1.044484e+06               False                 False
# 26       2325.0        5.405625e+06               False                 False
# 27       2054.0        4.218916e+06               False                 False
# 28       2065.0        4.264225e+06               False                  True
# 29       2358.0        5.560164e+06               False                 False
# ..          ...                 ...                 ...                   ...
# 318      3642.0        1.326416e+07               False                 False
# 319       615.0        3.782250e+05               False                 False
# 320     12195.0        1.487180e+08               False                  True
# 321     61686.0        3.805163e+09                True                  True
# 322     27980.0        7.828804e+08               False                  True
# 323      6887.0        4.743077e+07                True                  True
# 324     27940.0        7.806436e+08               False                  True
# 325      3012.0        9.072144e+06               False                 False
# 326      3453.0        1.192321e+07               False                 False
# 327      5828.0        3.396558e+07               False                  True
# 328      8392.0        7.042566e+07               False                 False
# 329      5175.0        2.678062e+07               False                  True
# 330     28179.0        7.940560e+08               False                  True
# 331     10245.0        1.049600e+08                True                  True
# 332      1862.0        3.467044e+06               False                 False
# 333      4337.0        1.880957e+07               False                  True
# 334     43777.0        1.916426e+09               False                  True
# 335      1797.0        3.229209e+06               False                 False
# 336      4574.0        2.092148e+07               False                 False
# 337      1732.0        2.999824e+06               False                 False
# 338     44821.0        2.008922e+09                True                  True
# 339      2604.0        6.780816e+06               False                 False
# 340     57559.0        3.313038e+09                True                  True
# 341      3733.0        1.393529e+07               False                 False
# 342      9141.0        8.355788e+07               False                 False
# 343     10685.0        1.141692e+08               False                  True
# 344       829.0        6.872410e+05               False                 False
# 345      5931.0        3.517676e+07               False                 False
# 346    199134.0        3.965435e+10                True                  True
# 347     36643.0        1.342709e+09               False                  True
#
#      Property_Crime
# 0              12.0
# 1              24.0
# 2              16.0
# 3            4090.0
# 4             223.0
# 5              46.0
# 6              10.0
# 7            2118.0
# 8             210.0
# 9             405.0
# 10             39.0
# 11             33.0
# 12              2.0
# 13              5.0
# 14            859.0
# 15             25.0
# 16             88.0
# 17             94.0
# 18            559.0
# 19            191.0
# 20            156.0
# 21            442.0
# 22           2349.0
# 23             14.0
# 24             99.0
# 25              4.0
# 26             24.0
# 27             20.0
# 28             31.0
# 29             13.0
# ..              ...
# 318            83.0
# 319             0.0
# 320           437.0
# 321          2528.0
# 322           571.0
# 323           142.0
# 324           767.0
# 325            68.0
# 326            78.0
# 327            58.0
# 328            59.0
# 329           194.0
# 330          1165.0
# 331           242.0
# 332            92.0
# 333            54.0
# 334           469.0
# 335            25.0
# 336           164.0
# 337            44.0
# 338           896.0
# 339            62.0
# 340          1232.0
# 341            36.0
# 342            77.0
# 343           541.0
# 344            17.0
# 345            58.0
# 346          2368.0
# 347           334.0
#
# [348 rows x 5 columns]
